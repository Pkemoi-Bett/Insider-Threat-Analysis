# %% [markdown]
# <a href="https://colab.research.google.com/github/Pkemoi-Bett/Insider-Threat/blob/main/Feature_selection_for_Attack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestRegressor
import sklearn as sk
import time
seconds = time.time()

print("Start of feature selection for Attack Process")

#Function to create a folder named "feaure_pics" in the program directory.
def folder(f_name):
    try:
        if not os.path.exists(f_name):
            os.makedirs(f_name)
    except OSError:
        print ("The folder could not be created!")

# CSV files names:
csv_files=os.listdir("attacks")# It creates a list of file names in the "attacks" folder.

# Headers of column
main_labels=["Flow Duration","Total Fwd Packets",   "Total Backward Packets","Total Length of Fwd Packets","Total Length of Bwd Packets","Fwd Packet Length Max","Fwd Packet Length Min",
   "Fwd Packet Length Mean","Fwd Packet Length Std","Bwd Packet Length Max","Bwd Packet Length Min","Bwd Packet Length Mean","Bwd Packet Length Std",
   "Flow Bytes/s","Flow Packets/s","Flow IAT Mean","Flow IAT Std","Flow IAT Max","Flow IAT Min","Fwd IAT Total","Fwd IAT Mean","Fwd IAT Std","Fwd IAT Max",
   "Fwd IAT Min","Bwd IAT Total","Bwd IAT Mean","Bwd IAT Std","Bwd IAT Max","Bwd IAT Min","Fwd PSH Flags","Bwd PSH Flags","Fwd URG Flags","Bwd URG Flags",
   "Fwd Header Length","Bwd Header Length","Fwd Packets/s","Bwd Packets/s","Min Packet Length","Max Packet Length","Packet Length Mean","Packet Length Std",
   "Packet Length Variance","FIN Flag Count","SYN Flag Count","RST Flag Count","PSH Flag Count","ACK Flag Count","URG Flag Count","CWE Flag Count",
   "ECE Flag Count","Down/Up Ratio","Average Packet Size","Avg Fwd Segment Size","Avg Bwd Segment Size","Fwd Avg Bytes/Bulk",
   "Fwd Avg Packets/Bulk","Fwd Avg Bulk Rate","Bwd Avg Bytes/Bulk","Bwd Avg Packets/Bulk","Bwd Avg Bulk Rate","Subflow Fwd Packets","Subflow Fwd Bytes",
   "Subflow Bwd Packets","Subflow Bwd Bytes","Init_Win_bytes_forward","Init_Win_bytes_backward","act_data_pkt_fwd",
   "min_seg_size_forward","Active Mean","Active Std","Active Max","Active Min",
    "Idle Mean","Idle Std","Idle Max", "Idle Min","Label"]

ths = open("importance_list_for_attack_files.csv", "w")
folder("./feaure_pics/")
for j in csv_files:
    df=pd.read_csv(".\\attacks\\"+j,usecols=main_labels)
    df=df.fillna(0)
    attack_or_not=[]
    for i in df["Label"]:#it changes the normal label to "1" and the attack tag to "0" for use in the machine learning algorithm
        if i =="BENIGN":
            attack_or_not.append(1)
        else:
            attack_or_not.append(0)
    df["Label"]=attack_or_not

    y = df["Label"].values
    del df["Label"]
    X = df.values

    X = np.float32(X)
    X[np.isnan(X)] = 0
    X[np.isinf(X)] = 0


    #computing the feature importances
    forest = sk.ensemble.RandomForestRegressor(n_estimators=250,random_state=0)
    forest.fit(X, y)
    importances = forest.feature_importances_
    std = np.std([tree.feature_importances_ for tree in forest.estimators_],
                 axis=0)
    indices = np.argsort(importances)[::-1]
    refclasscol=list(df.columns.values)
    impor_bars = pd.DataFrame({'Features':refclasscol[0:20],'importance':importances[0:20]})
    impor_bars = impor_bars.sort_values('importance',ascending=False).set_index('Features')
    plt.rcParams['figure.figsize'] = (10, 5)
    impor_bars.plot.bar();
    #printing the feature importances
    count=0
    fea_ture=j[0:-4]+"=["
    for i in impor_bars.index:
        fea_ture=fea_ture+"\""+str(i)+"\","
        count+=1
        if count==5:
            fea_ture=fea_ture[0:-1]+"]"
            break
    print(j[0:-4],"importance list:")
    print(j[0:-4],"\n",impor_bars.head(20),"\n\n\n")
    print(fea_ture)
    plt.title(j[0:-4]+" Attack - Feature Importance")
    plt.ylabel('Importance')

    plt.savefig("./feaure_pics/"+j[0:-4]+".pdf", bbox_inches='tight', orientation='portrait', format='pdf')

    #plt.savefig("./feaure_pics/"+j[0:-4]+".pdf",bbox_inches='tight', papertype = 'a4', orientation = 'portrait', format = 'pdf')
    ths.write((  fea_ture ) )
    plt.tight_layout()
    plt.show()
    print("-----------------------------------------------------------------------------------------------\n\n\n\n")


print("Feature selection for Attack has been completed!")
print("Total operation time: = ",time.time()- seconds ,"seconds")
ths.close()
# Out:
# Start of feature selection for Attack Process
# PortScan importance list:
# PortScan
#                                 importance
# Features
# Total Length of Fwd Packets  3.072260e-01
# Flow Bytes/s                 3.069069e-01
# Flow Duration                1.029331e-03
# Fwd IAT Total                9.680421e-04
# Flow IAT Max                 3.573179e-04
# Flow IAT Mean                2.149212e-04
# Fwd Packet Length Max        1.369654e-04
# Total Length of Bwd Packets  7.773855e-05
# Bwd Packet Length Min        6.358621e-05
# Flow Packets/s               6.043232e-05
# Bwd Packet Length Max        3.805756e-05
# Bwd Packet Length Mean       3.725950e-05
# Fwd Packet Length Mean       3.502598e-05
# Bwd Packet Length Std        2.043908e-05
# Flow IAT Min                 1.951879e-05
# Total Fwd Packets            1.499313e-05
# Flow IAT Std                 1.210407e-05
# Total Backward Packets       6.922742e-06
# Fwd Packet Length Std        6.725578e-06
# Fwd Packet Length Min        4.336101e-07
#
#
#
# PortScan=["Total Length of Fwd Packets","Flow Bytes/s","Flow Duration","Fwd IAT Total","Flow IAT Max"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Web Attack importance list:
# Web Attack
#                               importance
# Features
# Flow Duration                       0.0
# Total Fwd Packets                   0.0
# Flow IAT Min                        0.0
# Flow IAT Max                        0.0
# Flow IAT Std                        0.0
# Flow IAT Mean                       0.0
# Flow Packets/s                      0.0
# Flow Bytes/s                        0.0
# Bwd Packet Length Std               0.0
# Bwd Packet Length Mean              0.0
# Bwd Packet Length Min               0.0
# Bwd Packet Length Max               0.0
# Fwd Packet Length Std               0.0
# Fwd Packet Length Mean              0.0
# Fwd Packet Length Min               0.0
# Fwd Packet Length Max               0.0
# Total Length of Bwd Packets         0.0
# Total Length of Fwd Packets         0.0
# Total Backward Packets              0.0
# Fwd IAT Total                       0.0
#
#
#
# Web Attack=["Flow Duration","Total Fwd Packets","Flow IAT Min","Flow IAT Max","Flow IAT Std"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Infiltration importance list:
# Infiltration
#                               importance
# Features
# Total Fwd Packets              0.092033
# Flow Duration                  0.085468
# Flow IAT Max                   0.058814
# Total Length of Fwd Packets    0.048470
# Total Backward Packets         0.036797
# Fwd Packet Length Std          0.017626
# Fwd Packet Length Max          0.011267
# Bwd Packet Length Max          0.010064
# Bwd Packet Length Std          0.007673
# Bwd Packet Length Mean         0.006776
# Fwd IAT Total                  0.006246
# Flow IAT Std                   0.006016
# Flow Bytes/s                   0.005763
# Flow IAT Mean                  0.005455
# Fwd Packet Length Mean         0.004097
# Fwd Packet Length Min          0.003107
# Flow Packets/s                 0.002769
# Flow IAT Min                   0.002411
# Bwd Packet Length Min          0.001077
# Total Length of Bwd Packets    0.000352
#
#
#
# Infiltration=["Total Fwd Packets","Flow Duration","Flow IAT Max","Total Length of Fwd Packets","Total Backward Packets"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS slowloris importance list:
# DoS slowloris
#                               importance
# Features
# Flow IAT Mean                  0.477145
# Total Length of Bwd Packets    0.079396
# Bwd Packet Length Mean         0.034579
# Fwd IAT Total                  0.010647
# Total Fwd Packets              0.010495
# Flow IAT Min                   0.001025
# Flow Bytes/s                   0.000989
# Bwd Packet Length Std          0.000753
# Fwd Packet Length Std          0.000751
# Fwd Packet Length Max          0.000673
# Bwd Packet Length Max          0.000646
# Flow IAT Max                   0.000538
# Flow Duration                  0.000518
# Total Length of Fwd Packets    0.000508
# Fwd Packet Length Mean         0.000445
# Flow IAT Std                   0.000411
# Flow Packets/s                 0.000340
# Fwd Packet Length Min          0.000290
# Total Backward Packets         0.000246
# Bwd Packet Length Min          0.000004
#
#
#
# DoS slowloris=["Flow IAT Mean","Total Length of Bwd Packets","Bwd Packet Length Mean","Fwd IAT Total","Total Fwd Packets"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# SSH-Patator importance list:
# SSH-Patator
#                               importance
# Features
# Fwd Packet Length Max          0.000833
# Flow IAT Mean                  0.000613
# Flow IAT Max                   0.000509
# Flow Duration                  0.000489
# Total Length of Fwd Packets    0.000462
# Flow Packets/s                 0.000339
# Fwd IAT Total                  0.000280
# Flow IAT Std                   0.000272
# Flow IAT Min                   0.000180
# Fwd Packet Length Mean         0.000151
# Total Backward Packets         0.000135
# Fwd Packet Length Std          0.000129
# Bwd Packet Length Mean         0.000085
# Bwd Packet Length Max          0.000064
# Flow Bytes/s                   0.000059
# Total Length of Bwd Packets    0.000028
# Bwd Packet Length Std          0.000028
# Total Fwd Packets              0.000015
# Fwd Packet Length Min          0.000014
# Bwd Packet Length Min          0.000007
#
#
#
# SSH-Patator=["Fwd Packet Length Max","Flow IAT Mean","Flow IAT Max","Flow Duration","Total Length of Fwd Packets"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Bot importance list:
# Bot
#                               importance
# Features
# Bwd Packet Length Mean         0.363800
# Flow IAT Min                   0.019390
# Flow IAT Max                   0.015104
# Flow IAT Mean                  0.014044
# Flow Duration                  0.005597
# Flow IAT Std                   0.003900
# Flow Bytes/s                   0.002832
# Flow Packets/s                 0.000674
# Total Backward Packets         0.000494
# Total Length of Bwd Packets    0.000247
# Fwd IAT Total                  0.000209
# Total Fwd Packets              0.000177
# Bwd Packet Length Max          0.000151
# Fwd Packet Length Mean         0.000097
# Total Length of Fwd Packets    0.000088
# Bwd Packet Length Std          0.000079
# Bwd Packet Length Min          0.000061
# Fwd Packet Length Max          0.000059
# Fwd Packet Length Min          0.000042
# Fwd Packet Length Std          0.000013
#
#
#
# Bot=["Bwd Packet Length Mean","Flow IAT Min","Flow IAT Max","Flow IAT Mean","Flow Duration"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DDoS importance list:
# DDoS
#                               importance
# Features
# Bwd Packet Length Std          0.463401
# Total Backward Packets         0.095494
# Fwd IAT Total                  0.012296
# Flow Bytes/s                   0.007674
# Total Length of Fwd Packets    0.007498
# Flow IAT Min                   0.006334
# Flow Duration                  0.005877
# Flow IAT Std                   0.005508
# Flow IAT Mean                  0.005304
# Flow IAT Max                   0.004751
# Fwd Packet Length Max          0.001145
# Flow Packets/s                 0.001069
# Bwd Packet Length Max          0.000607
# Bwd Packet Length Min          0.000473
# Fwd Packet Length Std          0.000262
# Total Length of Bwd Packets    0.000228
# Bwd Packet Length Mean         0.000179
# Fwd Packet Length Mean         0.000149
# Total Fwd Packets              0.000034
# Fwd Packet Length Min          0.000016
#
#
#
# DDoS=["Bwd Packet Length Std","Total Backward Packets","Fwd IAT Total","Flow Bytes/s","Total Length of Fwd Packets"]
# -----------------------------------------------------------------------------------------------
